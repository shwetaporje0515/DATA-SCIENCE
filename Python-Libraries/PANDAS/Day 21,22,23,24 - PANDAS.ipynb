# %% [markdown]
# ## PANADAS
# - PANDAS IS A FAST, POWERFUL AND EASY TO USE OPEN SOURCE DATA ANALYSIS AND MANIPULATION LIBRARY
#
#       - SERIES
#       - DATAFRAME

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # SERIES

# %%
data = [10,20,30,40,50]
s1 = pd.Series(data)                        # Series is a class
s1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s1.values
# Out:
# array([10, 20, 30, 40, 50], dtype=int64)

# %%
list(s1.index)
# Out:
# [0, 1, 2, 3, 4]

# %%
s1.index = [101,102,103,104,105]
s1
# Out:
# 101    10
# 102    20
# 103    30
# 104    40
# 105    50
# dtype: int64

# %%
s1.index = ['a','b','c','d','e']
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
s1.index = range(1005,1010)
s1
# Out:
# 1005    10
# 1006    20
# 1007    30
# 1008    40
# 1009    50
# dtype: int64

# %%
s1.index = ['a','b','c','d','e']
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %% [markdown]
# ## ACCESSING DATA IN SERIES

# %%
s1[0]
# Out:
# C:\Users\sporj\AppData\Local\Temp\ipykernel_52420\643609873.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s1[0]
# 10

# %%
s1['a']
# Out:
# 10

# %%
s1.iloc[3]                  # iloc is used for default index
# Out:
# 40

# %%
s1.loc['d']                 # loc is used for default index
# Out:
# 40

# %% [markdown]
# ### ADD, UPDATE AND DELETE OPERATIONS

# %%
s1['f'] = 60             # add
s1
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
s1['c']=90             # update
s1
# Out:
# a    10
# b    20
# c    90
# d    40
# e    50
# f    60
# dtype: int64

# %%
s1.drop('d')        # this will show how it will look after deletion
# Out:
# a    10
# b    20
# c    90
# e    50
# f    60
# dtype: int64

# %%
s1                # but in reality it is not deleted
# Out:
# a    10
# b    20
# c    90
# d    40
# e    50
# f    60
# dtype: int64

# %%
s2 = s1.drop('d')              # to delete we need to store it into other variable to see the chngs like we have done here
s2
# Out:
# a    10
# b    20
# c    90
# e    50
# f    60
# dtype: int64

# %% [markdown]
# ### SLICING

# %%
s1[:]
# Out:
# a    10
# b    20
# c    90
# d    40
# e    50
# f    60
# dtype: int64

# %%
s1[2:4]
# Out:
# c    90
# d    40
# dtype: int64

# %%
s1[::-1]
# Out:
# f    60
# e    50
# d    40
# c    90
# b    20
# a    10
# dtype: int64

# %% [markdown]
# ### CREATING SERIES DATA FROM A DICTIONARY

# %%
data = {'jaipur'     : 'rajasthan', 
        'Mumbai'     : 'Maharashtra',
        'Kolkata'    : 'West bengal',
        'Chandigarh' : 'Punjab',
        'Lucknow'    : 'Uttar Pradesh'}

# %%
s2 = pd.Series(data)
s2
# Out:
# jaipur            rajasthan
# Mumbai          Maharashtra
# Kolkata         West bengal
# Chandigarh           Punjab
# Lucknow       Uttar Pradesh
# dtype: object

# %%
s2.iloc[2]
# Out:
# 'West bengal'

# %%
s2.loc['Kolkata']
# Out:
# 'West bengal'

# %%
s2.index
# Out:
# Index(['jaipur', 'Mumbai', 'Kolkata', 'Chandigarh', 'Lucknow'], dtype='object')

# %%
s2.values
# Out:
# array(['rajasthan', 'Maharashtra', 'West bengal', 'Punjab',
#        'Uttar Pradesh'], dtype=object)

# %%
s2.name = 'States and Capitals' 
s2
# Out:
# jaipur            rajasthan
# Mumbai          Maharashtra
# Kolkata         West bengal
# Chandigarh           Punjab
# Lucknow       Uttar Pradesh
# Name: States and Capitals, dtype: object

# %%
s2.index.name = 'Capitals'

# %%
s2
# Out:
# Capitals
# jaipur            rajasthan
# Mumbai          Maharashtra
# Kolkata         West bengal
# Chandigarh           Punjab
# Lucknow       Uttar Pradesh
# Name: States and Capitals, dtype: object

# %%
s2.loc['jaipur']
# Out:
# 'rajasthan'

# %%
s2.loc[['jaipur','Mumbai']]
# Out:
# Capitals
# jaipur      rajasthan
# Mumbai    Maharashtra
# Name: States and Capitals, dtype: object

# %%
s3 = pd.Series(data=s2,index=['jaipur','Mumbai','Delhi','Bangluru','Lucknow'])
s3
# Out:
# jaipur          rajasthan
# Mumbai        Maharashtra
# Delhi                 NaN
# Bangluru              NaN
# Lucknow     Uttar Pradesh
# Name: States and Capitals, dtype: object

# %% [markdown]
# ### FUNCTIONS

# %%
s3.isnull()
# Out:
# jaipur      False
# Mumbai      False
# Delhi        True
# Bangluru     True
# Lucknow     False
# Name: States and Capitals, dtype: bool

# %%
s3.isnull().sum()         # Using sum fun we are adding the value of null value
# Out:
# 2

# %%
s3.notnull()              # Opp of isnull
# Out:
# jaipur       True
# Mumbai       True
# Delhi       False
# Bangluru    False
# Lucknow      True
# Name: States and Capitals, dtype: bool

# %%
s3.notnull().sum()
# Out:
# 3

# %%
s3['Chandigarh'] = 'Punjab'
s3['Kolkata'] = 'West Bengal'
s3['Patna'] = 'Bihar'
s3
# Out:
# jaipur            rajasthan
# Mumbai          Maharashtra
# Delhi                   NaN
# Bangluru                NaN
# Lucknow       Uttar Pradesh
# Chandigarh           Punjab
# Kolkata         West Bengal
# Patna                 Bihar
# Name: States and Capitals, dtype: object

# %%
s3.head()
# Out:
# jaipur          rajasthan
# Mumbai        Maharashtra
# Delhi                 NaN
# Bangluru              NaN
# Lucknow     Uttar Pradesh
# Name: States and Capitals, dtype: object

# %%
s3.head(6)
# Out:
# jaipur            rajasthan
# Mumbai          Maharashtra
# Delhi                   NaN
# Bangluru                NaN
# Lucknow       Uttar Pradesh
# Chandigarh           Punjab
# Name: States and Capitals, dtype: object

# %%
s3.head(7)
# Out:
# jaipur            rajasthan
# Mumbai          Maharashtra
# Delhi                   NaN
# Bangluru                NaN
# Lucknow       Uttar Pradesh
# Chandigarh           Punjab
# Kolkata         West Bengal
# Name: States and Capitals, dtype: object

# %%
s3.tail()
# Out:
# Bangluru                NaN
# Lucknow       Uttar Pradesh
# Chandigarh           Punjab
# Kolkata         West Bengal
# Patna                 Bihar
# Name: States and Capitals, dtype: object

# %%
s3.tail(7)
# Out:
# Mumbai          Maharashtra
# Delhi                   NaN
# Bangluru                NaN
# Lucknow       Uttar Pradesh
# Chandigarh           Punjab
# Kolkata         West Bengal
# Patna                 Bihar
# Name: States and Capitals, dtype: object

# %%
s3.tail(2)
# Out:
# Kolkata    West Bengal
# Patna            Bihar
# Name: States and Capitals, dtype: object

# %%
s3['abc'] = 'Punjab'             # here punjab is repeated but it is accepted but duplicate keys are not accepted
s3
# Out:
# jaipur            rajasthan
# Mumbai          Maharashtra
# Delhi                   NaN
# Bangluru                NaN
# Lucknow       Uttar Pradesh
# Chandigarh           Punjab
# Kolkata         West Bengal
# Patna                 Bihar
# abc                  Punjab
# Name: States and Capitals, dtype: object

# %%
s3.duplicated()
# Out:
# jaipur        False
# Mumbai        False
# Delhi         False
# Bangluru       True
# Lucknow       False
# Chandigarh    False
# Kolkata       False
# Patna         False
# abc            True
# Name: States and Capitals, dtype: bool

# %%
s3.duplicated().sum()
# Out:
# 2

# %%
s3.drop_duplicates()                    #Duploicate va;ue will get deleted
# Out:
# jaipur            rajasthan
# Mumbai          Maharashtra
# Delhi                   NaN
# Lucknow       Uttar Pradesh
# Chandigarh           Punjab
# Kolkata         West Bengal
# Patna                 Bihar
# Name: States and Capitals, dtype: object

# %%
s3
# Out:
# jaipur            rajasthan
# Mumbai          Maharashtra
# Delhi                   NaN
# Bangluru                NaN
# Lucknow       Uttar Pradesh
# Chandigarh           Punjab
# Kolkata         West Bengal
# Patna                 Bihar
# abc                  Punjab
# Name: States and Capitals, dtype: object

# %%
s4 = s3.drop_duplicates()                  # Here the changes are permanant
s4
# Out:
# jaipur            rajasthan
# Mumbai          Maharashtra
# Delhi                   NaN
# Lucknow       Uttar Pradesh
# Chandigarh           Punjab
# Kolkata         West Bengal
# Patna                 Bihar
# Name: States and Capitals, dtype: object

# %% [markdown]
# ## DATAFRAMES

# %%
employee1 = pd.Series({'NAME' : 'ANKUR', 'GENDER' : 'MALE', 'SALARY' : 100000})
employee2 = pd.Series({'NAME' : 'ADITYA', 'GENDER' : 'MALE', 'SALARY' : 1500000})
employee3 = pd.Series({'NAME' : 'ARCHANA', 'GENDER' : 'FEMALE', 'SALARY' : 5300000})
employee4 = pd.Series({'NAME' : 'DEEPALI', 'GENDER' : 'FEMALE', 'SALARY' : 1300000})
employee5 = pd.Series({'NAME' : 'JAGJEET', 'GENDER' : 'MALE', 'SALARY' : 5600000})
employee6 = pd.Series({'NAME' : 'KEDAR', 'GENDER' : 'MALE', 'SALARY' : 3900000})
employee7 = pd.Series({'NAME' : 'MAHESH', 'GENDER' : 'MALE', 'SALARY' : 1350000})
employee8 = pd.Series({'NAME' : 'POOJA', 'GENDER' : 'FEMALE', 'SALARY' : 4520000})
employee9 = pd.Series({'NAME' : 'PRAPTI', 'GENDER' : 'FEMALE', 'SALARY' : 4530000})
employee10 = pd.Series({'NAME' : 'SHRUTIKA', 'GENDER' : 'FEMALE', 'SALARY' : 7850000})
employee11 = pd.Series({'NAME' : 'SIMRAN', 'GENDER' : 'FEMALE', 'SALARY' : 5980000})
employee12 = pd.Series({'NAME' : 'ASHUTOSH', 'GENDER' : 'MALE', 'SALARY' : 9800000})
employee13 = pd.Series({'NAME' : 'SURAJ', 'GENDER' : 'MALE', 'SALARY' : 8130000})
employee14 = pd.Series({'NAME' : 'SHWETA', 'GENDER' : 'FEMALE', 'SALARY' : 7260000})
employee15 = pd.Series({'NAME' : 'VEDIKA', 'GENDER' : 'FEMALE', 'SALARY' : 6360000})

# %%
employee = [employee1, employee2, employee3, employee4, employee5, employee6, employee7, employee8, employee9, employee10, employee11, employee12, employee13, employee14, employee15]
df = pd.DataFrame(data = employee, index = range(101,116))
df
# Out:
#          NAME  GENDER   SALARY
# 101     ANKUR    MALE   100000
# 102    ADITYA    MALE  1500000
# 103   ARCHANA  FEMALE  5300000
# 104   DEEPALI  FEMALE  1300000
# 105   JAGJEET    MALE  5600000
# 106     KEDAR    MALE  3900000
# 107    MAHESH    MALE  1350000
# 108     POOJA  FEMALE  4520000
# 109    PRAPTI  FEMALE  4530000
# 110  SHRUTIKA  FEMALE  7850000
# 111    SIMRAN  FEMALE  5980000
# 112  ASHUTOSH    MALE  9800000
# 113     SURAJ    MALE  8130000
# 114    SHWETA  FEMALE  7260000
# 115    VEDIKA  FEMALE  6360000

# %% [markdown]
# ### IMPORTING CSV FILE

# %% [raw]
# ## THis is how we can import the file from the folder
#
# df1 = pd.read_csv('drug200.csv')
# df1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 101 to 115
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    15 non-null     object
#  1   GENDER  15 non-null     object
#  2   SALARY  15 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 492.0+ bytes

# %%
df.head()
# Out:
#         NAME  GENDER   SALARY
# 101    ANKUR    MALE   100000
# 102   ADITYA    MALE  1500000
# 103  ARCHANA  FEMALE  5300000
# 104  DEEPALI  FEMALE  1300000
# 105  JAGJEET    MALE  5600000

# %%
df.tail()
# Out:
#          NAME  GENDER   SALARY
# 111    SIMRAN  FEMALE  5980000
# 112  ASHUTOSH    MALE  9800000
# 113     SURAJ    MALE  8130000
# 114    SHWETA  FEMALE  7260000
# 115    VEDIKA  FEMALE  6360000

# %%
df.name = 'Employee Details'
df.index.name = 'Employee ID'

# %%
df
# Out:
#                  NAME  GENDER   SALARY
# Employee ID
# 101             ANKUR    MALE   100000
# 102            ADITYA    MALE  1500000
# 103           ARCHANA  FEMALE  5300000
# 104           DEEPALI  FEMALE  1300000
# 105           JAGJEET    MALE  5600000
# 106             KEDAR    MALE  3900000
# 107            MAHESH    MALE  1350000
# 108             POOJA  FEMALE  4520000
# 109            PRAPTI  FEMALE  4530000
# 110          SHRUTIKA  FEMALE  7850000
# 111            SIMRAN  FEMALE  5980000
# 112          ASHUTOSH    MALE  9800000
# 113             SURAJ    MALE  8130000
# 114            SHWETA  FEMALE  7260000
# 115            VEDIKA  FEMALE  6360000

# %%
df.name
# Out:
# 'Employee Details'

# %%
df.columns
# Out:
# Index(['NAME', 'GENDER', 'SALARY'], dtype='object')

# %% [markdown]
# ## ACCESSING DATA FROM DATAFRAME

# %%
df
# Out:
#                  NAME  GENDER   SALARY
# Employee ID
# 101             ANKUR    MALE   100000
# 102            ADITYA    MALE  1500000
# 103           ARCHANA  FEMALE  5300000
# 104           DEEPALI  FEMALE  1300000
# 105           JAGJEET    MALE  5600000
# 106             KEDAR    MALE  3900000
# 107            MAHESH    MALE  1350000
# 108             POOJA  FEMALE  4520000
# 109            PRAPTI  FEMALE  4530000
# 110          SHRUTIKA  FEMALE  7850000
# 111            SIMRAN  FEMALE  5980000
# 112          ASHUTOSH    MALE  9800000
# 113             SURAJ    MALE  8130000
# 114            SHWETA  FEMALE  7260000
# 115            VEDIKA  FEMALE  6360000

# %%
df['NAME']               # it is in the data series format
# Out:
# Employee ID
# 101       ANKUR
# 102      ADITYA
# 103     ARCHANA
# 104     DEEPALI
# 105     JAGJEET
# 106       KEDAR
# 107      MAHESH
# 108       POOJA
# 109      PRAPTI
# 110    SHRUTIKA
# 111      SIMRAN
# 112    ASHUTOSH
# 113       SURAJ
# 114      SHWETA
# 115      VEDIKA
# Name: NAME, dtype: object

# %%
df['SALARY']                   # it is in the data series format
# Out:
# Employee ID
# 101     100000
# 102    1500000
# 103    5300000
# 104    1300000
# 105    5600000
# 106    3900000
# 107    1350000
# 108    4520000
# 109    4530000
# 110    7850000
# 111    5980000
# 112    9800000
# 113    8130000
# 114    7260000
# 115    6360000
# Name: SALARY, dtype: int64

# %%
df[['NAME']]                       # it is in the data dataframe format
# Out:
#                  NAME
# Employee ID
# 101             ANKUR
# 102            ADITYA
# 103           ARCHANA
# 104           DEEPALI
# 105           JAGJEET
# 106             KEDAR
# 107            MAHESH
# 108             POOJA
# 109            PRAPTI
# 110          SHRUTIKA
# 111            SIMRAN
# 112          ASHUTOSH
# 113             SURAJ
# 114            SHWETA
# 115            VEDIKA

# %%
df[['SALARY']]                          # it is in the data dataframe format
# Out:
#               SALARY
# Employee ID
# 101           100000
# 102          1500000
# 103          5300000
# 104          1300000
# 105          5600000
# 106          3900000
# 107          1350000
# 108          4520000
# 109          4530000
# 110          7850000
# 111          5980000
# 112          9800000
# 113          8130000
# 114          7260000
# 115          6360000

# %%
df[['NAME','SALARY']]                         # HERE THERE ARE 2 CLMS THEN WE CANT GIVE SINGLE BRACKET WE HAVE TO USE 2 BRACKETS BCOZ OF THERE ARE TWO COLUMNS THEN IT IS THE DATAFRAME NOT DATASERIES
# Out:
#                  NAME   SALARY
# Employee ID
# 101             ANKUR   100000
# 102            ADITYA  1500000
# 103           ARCHANA  5300000
# 104           DEEPALI  1300000
# 105           JAGJEET  5600000
# 106             KEDAR  3900000
# 107            MAHESH  1350000
# 108             POOJA  4520000
# 109            PRAPTI  4530000
# 110          SHRUTIKA  7850000
# 111            SIMRAN  5980000
# 112          ASHUTOSH  9800000
# 113             SURAJ  8130000
# 114            SHWETA  7260000
# 115            VEDIKA  6360000

# %%
df[['NAME','GENDER','SALARY']]
# Out:
#                  NAME  GENDER   SALARY
# Employee ID
# 101             ANKUR    MALE   100000
# 102            ADITYA    MALE  1500000
# 103           ARCHANA  FEMALE  5300000
# 104           DEEPALI  FEMALE  1300000
# 105           JAGJEET    MALE  5600000
# 106             KEDAR    MALE  3900000
# 107            MAHESH    MALE  1350000
# 108             POOJA  FEMALE  4520000
# 109            PRAPTI  FEMALE  4530000
# 110          SHRUTIKA  FEMALE  7850000
# 111            SIMRAN  FEMALE  5980000
# 112          ASHUTOSH    MALE  9800000
# 113             SURAJ    MALE  8130000
# 114            SHWETA  FEMALE  7260000
# 115            VEDIKA  FEMALE  6360000

# %%
cols = ['NAME','SALARY']                # 2 meth of above
df[cols]
# Out:
#                  NAME   SALARY
# Employee ID
# 101             ANKUR   100000
# 102            ADITYA  1500000
# 103           ARCHANA  5300000
# 104           DEEPALI  1300000
# 105           JAGJEET  5600000
# 106             KEDAR  3900000
# 107            MAHESH  1350000
# 108             POOJA  4520000
# 109            PRAPTI  4530000
# 110          SHRUTIKA  7850000
# 111            SIMRAN  5980000
# 112          ASHUTOSH  9800000
# 113             SURAJ  8130000
# 114            SHWETA  7260000
# 115            VEDIKA  6360000

# %%
df.NAME
# Out:
# Employee ID
# 101       ANKUR
# 102      ADITYA
# 103     ARCHANA
# 104     DEEPALI
# 105     JAGJEET
# 106       KEDAR
# 107      MAHESH
# 108       POOJA
# 109      PRAPTI
# 110    SHRUTIKA
# 111      SIMRAN
# 112    ASHUTOSH
# 113       SURAJ
# 114      SHWETA
# 115      VEDIKA
# Name: NAME, dtype: object

# %%
df.loc[104]
# Out:
# NAME      DEEPALI
# GENDER     FEMALE
# SALARY    1300000
# Name: 104, dtype: object

# %%
df.loc[[104]]
# Out:
#                 NAME  GENDER   SALARY
# Employee ID
# 104          DEEPALI  FEMALE  1300000

# %%
df.loc[[111]]
# Out:
#                NAME  GENDER   SALARY
# Employee ID
# 111          SIMRAN  FEMALE  5980000

# %%
df.iloc[[3]]               # iloc = default index
# Out:
#                 NAME  GENDER   SALARY
# Employee ID
# 104          DEEPALI  FEMALE  1300000

# %%
df.iloc[[6]]
# Out:
#                NAME GENDER   SALARY
# Employee ID
# 107          MAHESH   MALE  1350000

# %%
df.loc[[107]]
# Out:
#                NAME GENDER   SALARY
# Employee ID
# 107          MAHESH   MALE  1350000

# %%
df.loc[[101,105]]
# Out:
#                 NAME GENDER   SALARY
# Employee ID
# 101            ANKUR   MALE   100000
# 105          JAGJEET   MALE  5600000

# %%
df.loc[[102,105,106,107,115]]
# Out:
#                 NAME  GENDER   SALARY
# Employee ID
# 102           ADITYA    MALE  1500000
# 105          JAGJEET    MALE  5600000
# 106            KEDAR    MALE  3900000
# 107           MAHESH    MALE  1350000
# 115           VEDIKA  FEMALE  6360000

# %%
df.iloc[[0,4,5,6,7,14]]
# Out:
#                 NAME  GENDER   SALARY
# Employee ID
# 101            ANKUR    MALE   100000
# 105          JAGJEET    MALE  5600000
# 106            KEDAR    MALE  3900000
# 107           MAHESH    MALE  1350000
# 108            POOJA  FEMALE  4520000
# 115           VEDIKA  FEMALE  6360000

# %% [markdown]
# ### ACCESSING SPECIFIC VALUES

# %%
df.SALARY
# Out:
# Employee ID
# 101     100000
# 102    1500000
# 103    5300000
# 104    1300000
# 105    5600000
# 106    3900000
# 107    1350000
# 108    4520000
# 109    4530000
# 110    7850000
# 111    5980000
# 112    9800000
# 113    8130000
# 114    7260000
# 115    6360000
# Name: SALARY, dtype: int64

# %%
df.SALARY[109]
# Out:
# 4530000

# %%
df['SALARY'][109]
# Out:
# 4530000

# %%
df[109]['SALARY']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 109
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df[109]['SALARY']
#
# ...

# %%
df.loc[109]['SALARY']
# Out:
# 4530000

# %%
df.loc[109,'SALARY']
# Out:
# 4530000

# %%
df.iloc[8]['SALARY']             # CANT GIVE QUAMA SEPARATED VALUE LIKE ABOVE IN ILOC
# Out:
# 4530000

# %%
df['SALARY'][8]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:414, in RangeIndex.get_loc(self, key)
#     413 try:
# --> 414     return self._range.index(new_key)
#     415 except ValueError as err:
#
# ValueError: 8 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df['SALARY'][8]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# ...

# %%
df['SALARY',8]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('SALARY', 8)
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df['SALARY',8]
#
# ...

# %%
df.loc[108,'NAME']
# Out:
# 'POOJA'

# %%
df.iloc[7]['NAME']
# Out:
# 'POOJA'

# %%
df.loc[[102,103,104,105,]]['SALARY']
# Out:
# Employee ID
# 102    1500000
# 103    5300000
# 104    1300000
# 105    5600000
# Name: SALARY, dtype: int64

# %%
df.loc[[102,103,104,105,]][['NAME','SALARY']]
# Out:
#                 NAME   SALARY
# Employee ID
# 102           ADITYA  1500000
# 103          ARCHANA  5300000
# 104          DEEPALI  1300000
# 105          JAGJEET  5600000

# %%
df.loc[[102,103,104,105],['NAME','SALARY']]
# Out:
#                 NAME   SALARY
# Employee ID
# 102           ADITYA  1500000
# 103          ARCHANA  5300000
# 104          DEEPALI  1300000
# 105          JAGJEET  5600000

# %%
df.loc[102::2]
# Out:
#                  NAME  GENDER   SALARY
# Employee ID
# 102            ADITYA    MALE  1500000
# 104           DEEPALI  FEMALE  1300000
# 106             KEDAR    MALE  3900000
# 108             POOJA  FEMALE  4520000
# 110          SHRUTIKA  FEMALE  7850000
# 112          ASHUTOSH    MALE  9800000
# 114            SHWETA  FEMALE  7260000

# %%
df.loc[102::2][['SALARY']]
# Out:
#               SALARY
# Employee ID
# 102          1500000
# 104          1300000
# 106          3900000
# 108          4520000
# 110          7850000
# 112          9800000
# 114          7260000

# %%
df.iloc[1:15:2]
# Out:
#                  NAME  GENDER   SALARY
# Employee ID
# 102            ADITYA    MALE  1500000
# 104           DEEPALI  FEMALE  1300000
# 106             KEDAR    MALE  3900000
# 108             POOJA  FEMALE  4520000
# 110          SHRUTIKA  FEMALE  7850000
# 112          ASHUTOSH    MALE  9800000
# 114            SHWETA  FEMALE  7260000

# %% [markdown]
# ### ADDING AND DELETING ROWS AND COLUMNS

# %%
df
# Out:
#                  NAME  GENDER   SALARY
# Employee ID
# 101             ANKUR    MALE   100000
# 102            ADITYA    MALE  1500000
# 103           ARCHANA  FEMALE  5300000
# 104           DEEPALI  FEMALE  1300000
# 105           JAGJEET    MALE  5600000
# 106             KEDAR    MALE  3900000
# 107            MAHESH    MALE  1350000
# 108             POOJA  FEMALE  4520000
# 109            PRAPTI  FEMALE  4530000
# 110          SHRUTIKA  FEMALE  7850000
# 111            SIMRAN  FEMALE  5980000
# 112          ASHUTOSH    MALE  9800000
# 113             SURAJ    MALE  8130000
# 114            SHWETA  FEMALE  7260000
# 115            VEDIKA  FEMALE  6360000

# %%
df.loc[116] = ['VIVEK', 'MALE', 1560000]              # this is how ne value to the row we can add new value
df
# Out:
#                  NAME  GENDER   SALARY
# Employee ID
# 101             ANKUR    MALE   100000
# 102            ADITYA    MALE  1500000
# 103           ARCHANA  FEMALE  5300000
# 104           DEEPALI  FEMALE  1300000
# 105           JAGJEET    MALE  5600000
# 106             KEDAR    MALE  3900000
# 107            MAHESH    MALE  1350000
# 108             POOJA  FEMALE  4520000
# 109            PRAPTI  FEMALE  4530000
# 110          SHRUTIKA  FEMALE  7850000
# 111            SIMRAN  FEMALE  5980000
# 112          ASHUTOSH    MALE  9800000
# 113             SURAJ    MALE  8130000
# 114            SHWETA  FEMALE  7260000
# 115            VEDIKA  FEMALE  6360000
# 116             VIVEK    MALE  1560000

# %%
df['AGE'] = np.random.randint(25,50,16)                     # This is how column can be added
df
# Out:
#                  NAME  GENDER   SALARY  AGE
# Employee ID
# 101             ANKUR    MALE   100000   39
# 102            ADITYA    MALE  1500000   28
# 103           ARCHANA  FEMALE  5300000   40
# 104           DEEPALI  FEMALE  1300000   30
# 105           JAGJEET    MALE  5600000   44
# 106             KEDAR    MALE  3900000   39
# 107            MAHESH    MALE  1350000   43
# 108             POOJA  FEMALE  4520000   32
# 109            PRAPTI  FEMALE  4530000   39
# 110          SHRUTIKA  FEMALE  7850000   42
# 111            SIMRAN  FEMALE  5980000   34
# 112          ASHUTOSH    MALE  9800000   36
# 113             SURAJ    MALE  8130000   47
# 114            SHWETA  FEMALE  7260000   47
# 115            VEDIKA  FEMALE  6360000   44
# 116             VIVEK    MALE  1560000   45

# %%
df['CITY'] = 'PUNE'
df
# Out:
#                  NAME  GENDER   SALARY  AGE  CITY
# Employee ID
# 101             ANKUR    MALE   100000   39  PUNE
# 102            ADITYA    MALE  1500000   28  PUNE
# 103           ARCHANA  FEMALE  5300000   40  PUNE
# 104           DEEPALI  FEMALE  1300000   30  PUNE
# 105           JAGJEET    MALE  5600000   44  PUNE
# 106             KEDAR    MALE  3900000   39  PUNE
# 107            MAHESH    MALE  1350000   43  PUNE
# 108             POOJA  FEMALE  4520000   32  PUNE
# 109            PRAPTI  FEMALE  4530000   39  PUNE
# 110          SHRUTIKA  FEMALE  7850000   42  PUNE
# 111            SIMRAN  FEMALE  5980000   34  PUNE
# 112          ASHUTOSH    MALE  9800000   36  PUNE
# 113             SURAJ    MALE  8130000   47  PUNE
# 114            SHWETA  FEMALE  7260000   47  PUNE
# 115            VEDIKA  FEMALE  6360000   44  PUNE
# 116             VIVEK    MALE  1560000   45  PUNE

# %%
df.drop('CITY', axis = 1, inplace = True)             # Axis 1 for column wise

# %%
df
# Out:
#                  NAME  GENDER   SALARY  AGE
# Employee ID
# 101             ANKUR    MALE   100000   39
# 102            ADITYA    MALE  1500000   28
# 103           ARCHANA  FEMALE  5300000   40
# 104           DEEPALI  FEMALE  1300000   30
# 105           JAGJEET    MALE  5600000   44
# 106             KEDAR    MALE  3900000   39
# 107            MAHESH    MALE  1350000   43
# 108             POOJA  FEMALE  4520000   32
# 109            PRAPTI  FEMALE  4530000   39
# 110          SHRUTIKA  FEMALE  7850000   42
# 111            SIMRAN  FEMALE  5980000   34
# 112          ASHUTOSH    MALE  9800000   36
# 113             SURAJ    MALE  8130000   47
# 114            SHWETA  FEMALE  7260000   47
# 115            VEDIKA  FEMALE  6360000   44
# 116             VIVEK    MALE  1560000   45

# %%
df.drop(116, axis = 0, inplace = True)                  # Axis 0 for rowwise

# %%
df
# Out:
#                  NAME  GENDER   SALARY  AGE
# Employee ID
# 101             ANKUR    MALE   100000   39
# 102            ADITYA    MALE  1500000   28
# 103           ARCHANA  FEMALE  5300000   40
# 104           DEEPALI  FEMALE  1300000   30
# 105           JAGJEET    MALE  5600000   44
# 106             KEDAR    MALE  3900000   39
# 107            MAHESH    MALE  1350000   43
# 108             POOJA  FEMALE  4520000   32
# 109            PRAPTI  FEMALE  4530000   39
# 110          SHRUTIKA  FEMALE  7850000   42
# 111            SIMRAN  FEMALE  5980000   34
# 112          ASHUTOSH    MALE  9800000   36
# 113             SURAJ    MALE  8130000   47
# 114            SHWETA  FEMALE  7260000   47
# 115            VEDIKA  FEMALE  6360000   44

# %%
n = input('Enter the name of the employee : ')
g = input('Enter the gender of the employee : ')
s = int(input('Enter the salary of the employee : '))
a = int(input('Enter the age of the employee : '))

df.loc[116] = [n,g,s,a]
df
# Out:
# Enter the name of the employee :  HARISH
# Enter the gender of the employee :  MALE
# Enter the salary of the employee :  45610000
# Enter the age of the employee :  42
#                  NAME  GENDER    SALARY  AGE
# Employee ID
# 101             ANKUR    MALE    100000   39
# 102            ADITYA    MALE   1500000   28
# 103           ARCHANA  FEMALE   5300000   40
# 104           DEEPALI  FEMALE   1300000   30
# 105           JAGJEET    MALE   5600000   44
# 106             KEDAR    MALE   3900000   39
# 107            MAHESH    MALE   1350000   43
# 108             POOJA  FEMALE   4520000   32
# 109            PRAPTI  FEMALE   4530000   39
# 110          SHRUTIKA  FEMALE   7850000   42
# 111            SIMRAN  FEMALE   5980000   34
# 112          ASHUTOSH    MALE   9800000   36
# 113             SURAJ    MALE   8130000   47
# 114            SHWETA  FEMALE   7260000   47
# 115            VEDIKA  FEMALE   6360000   44
# 116            HARISH    MALE  45610000   42

# %%
df[df.AGE>40]
# Out:
#                  NAME  GENDER    SALARY  AGE
# Employee ID
# 105           JAGJEET    MALE   5600000   44
# 107            MAHESH    MALE   1350000   43
# 110          SHRUTIKA  FEMALE   7850000   42
# 113             SURAJ    MALE   8130000   47
# 114            SHWETA  FEMALE   7260000   47
# 115            VEDIKA  FEMALE   6360000   44
# 116            HARISH    MALE  45610000   42

# %%
df[df.AGE>40][['NAME','SALARY']]
# Out:
#                  NAME    SALARY
# Employee ID
# 105           JAGJEET   5600000
# 107            MAHESH   1350000
# 110          SHRUTIKA   7850000
# 113             SURAJ   8130000
# 114            SHWETA   7260000
# 115            VEDIKA   6360000
# 116            HARISH  45610000

# %%
df[df.NAME == 'ANKUR']
# Out:
#               NAME GENDER  SALARY  AGE
# Employee ID
# 101          ANKUR   MALE  100000   39

# %%
df[df.GENDER == 'FEMALE']
# Out:
#                  NAME  GENDER   SALARY  AGE
# Employee ID
# 103           ARCHANA  FEMALE  5300000   40
# 104           DEEPALI  FEMALE  1300000   30
# 108             POOJA  FEMALE  4520000   32
# 109            PRAPTI  FEMALE  4530000   39
# 110          SHRUTIKA  FEMALE  7850000   42
# 111            SIMRAN  FEMALE  5980000   34
# 114            SHWETA  FEMALE  7260000   47
# 115            VEDIKA  FEMALE  6360000   44

# %%
df[df.GENDER == 'MALE'][df.SALARY > 11000000]
# Out:
# C:\Users\sporj\AppData\Local\Temp\ipykernel_52420\3945920359.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.GENDER == 'MALE'][df.SALARY > 11000000]
#                NAME GENDER    SALARY  AGE
# Employee ID
# 116          HARISH   MALE  45610000   42

# %%
df[df.GENDER == 'MALE'][df.SALARY > 4500000] [df.AGE > 42]
# Out:
# C:\Users\sporj\AppData\Local\Temp\ipykernel_52420\1037852601.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.GENDER == 'MALE'][df.SALARY > 4500000] [df.AGE > 42]
# C:\Users\sporj\AppData\Local\Temp\ipykernel_52420\1037852601.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.GENDER == 'MALE'][df.SALARY > 4500000] [df.AGE > 42]
#                 NAME GENDER   SALARY  AGE
# Employee ID
# 105          JAGJEET   MALE  5600000   44
# 113            SURAJ   MALE  8130000   47

# %% [markdown]
# ### IMPORTANT FUNCTIONS

# %%
df
# Out:
#                  NAME  GENDER    SALARY  AGE
# Employee ID
# 101             ANKUR    MALE    100000   39
# 102            ADITYA    MALE   1500000   28
# 103           ARCHANA  FEMALE   5300000   40
# 104           DEEPALI  FEMALE   1300000   30
# 105           JAGJEET    MALE   5600000   44
# 106             KEDAR    MALE   3900000   39
# 107            MAHESH    MALE   1350000   43
# 108             POOJA  FEMALE   4520000   32
# 109            PRAPTI  FEMALE   4530000   39
# 110          SHRUTIKA  FEMALE   7850000   42
# 111            SIMRAN  FEMALE   5980000   34
# 112          ASHUTOSH    MALE   9800000   36
# 113             SURAJ    MALE   8130000   47
# 114            SHWETA  FEMALE   7260000   47
# 115            VEDIKA  FEMALE   6360000   44
# 116            HARISH    MALE  45610000   42

# %%
df.loc[117] = df.loc[106]
df.loc[118] = df.loc[108]

df.loc[119] = ['ANKUSH', 'MALE', np.nan, 32]
df.loc[120] = ['KRISHNA', 'MALE', np.nan, 22]
df
# Out:
#                  NAME  GENDER      SALARY  AGE
# Employee ID
# 101             ANKUR    MALE    100000.0   39
# 102            ADITYA    MALE   1500000.0   28
# 103           ARCHANA  FEMALE   5300000.0   40
# 104           DEEPALI  FEMALE   1300000.0   30
# 105           JAGJEET    MALE   5600000.0   44
# 106             KEDAR    MALE   3900000.0   39
# 107            MAHESH    MALE   1350000.0   43
# 108             POOJA  FEMALE   4520000.0   32
# 109            PRAPTI  FEMALE   4530000.0   39
# 110          SHRUTIKA  FEMALE   7850000.0   42
# 111            SIMRAN  FEMALE   5980000.0   34
# 112          ASHUTOSH    MALE   9800000.0   36
# 113             SURAJ    MALE   8130000.0   47
# 114            SHWETA  FEMALE   7260000.0   47
# 115            VEDIKA  FEMALE   6360000.0   44
# 116            HARISH    MALE  45610000.0   42
# 117             KEDAR    MALE   3900000.0   39
# 118             POOJA  FEMALE   4520000.0   32
# 119            ANKUSH    MALE         NaN   32
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 101 to 120
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NAME    20 non-null     object
#  1   GENDER  20 non-null     object
#  2   SALARY  18 non-null     float64
#  3   AGE     20 non-null     int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 800.0+ bytes

# %%
df.head()
# Out:
#                 NAME  GENDER     SALARY  AGE
# Employee ID
# 101            ANKUR    MALE   100000.0   39
# 102           ADITYA    MALE  1500000.0   28
# 103          ARCHANA  FEMALE  5300000.0   40
# 104          DEEPALI  FEMALE  1300000.0   30
# 105          JAGJEET    MALE  5600000.0   44

# %%
df.tail()
# Out:
#                 NAME  GENDER      SALARY  AGE
# Employee ID
# 116           HARISH    MALE  45610000.0   42
# 117            KEDAR    MALE   3900000.0   39
# 118            POOJA  FEMALE   4520000.0   32
# 119           ANKUSH    MALE         NaN   32
# 120          KRISHNA    MALE         NaN   22

# %%
df.isnull().sum()
# Out:
# NAME      0
# GENDER    0
# SALARY    2
# AGE       0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# NAME      20
# GENDER    20
# SALARY    18
# AGE       20
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.nunique()
# Out:
# NAME      18
# GENDER     2
# SALARY    16
# AGE       12
# dtype: int64

# %%
df.NAME.unique()
# Out:
# array(['ANKUR', 'ADITYA', 'ARCHANA', 'DEEPALI', 'JAGJEET', 'KEDAR',
#        'MAHESH', 'POOJA', 'PRAPTI', 'SHRUTIKA', 'SIMRAN', 'ASHUTOSH',
#        'SURAJ', 'SHWETA', 'VEDIKA', 'HARISH', 'ANKUSH', 'KRISHNA'],
#       dtype=object)

# %%
df['NAME'].unique()
# Out:
# array(['ANKUR', 'ADITYA', 'ARCHANA', 'DEEPALI', 'JAGJEET', 'KEDAR',
#        'MAHESH', 'POOJA', 'PRAPTI', 'SHRUTIKA', 'SIMRAN', 'ASHUTOSH',
#        'SURAJ', 'SHWETA', 'VEDIKA', 'HARISH', 'ANKUSH', 'KRISHNA'],
#       dtype=object)

# %%
df.AGE.unique()
# Out:
# array([39, 28, 40, 30, 44, 43, 32, 42, 34, 36, 47, 22], dtype=int64)

# %%
df.sort_values(by = 'NAME')
# Out:
#                  NAME  GENDER      SALARY  AGE
# Employee ID
# 102            ADITYA    MALE   1500000.0   28
# 101             ANKUR    MALE    100000.0   39
# 119            ANKUSH    MALE         NaN   32
# 103           ARCHANA  FEMALE   5300000.0   40
# 112          ASHUTOSH    MALE   9800000.0   36
# 104           DEEPALI  FEMALE   1300000.0   30
# 116            HARISH    MALE  45610000.0   42
# 105           JAGJEET    MALE   5600000.0   44
# 106             KEDAR    MALE   3900000.0   39
# 117             KEDAR    MALE   3900000.0   39
# 120           KRISHNA    MALE         NaN   22
# 107            MAHESH    MALE   1350000.0   43
# 108             POOJA  FEMALE   4520000.0   32
# 118             POOJA  FEMALE   4520000.0   32
# 109            PRAPTI  FEMALE   4530000.0   39
# 110          SHRUTIKA  FEMALE   7850000.0   42
# 114            SHWETA  FEMALE   7260000.0   47
# 111            SIMRAN  FEMALE   5980000.0   34
# 113             SURAJ    MALE   8130000.0   47
# ...

# %%
df.sort_values(by = 'NAME', ascending = False)
# Out:
#                  NAME  GENDER      SALARY  AGE
# Employee ID
# 115            VEDIKA  FEMALE   6360000.0   44
# 113             SURAJ    MALE   8130000.0   47
# 111            SIMRAN  FEMALE   5980000.0   34
# 114            SHWETA  FEMALE   7260000.0   47
# 110          SHRUTIKA  FEMALE   7850000.0   42
# 109            PRAPTI  FEMALE   4530000.0   39
# 118             POOJA  FEMALE   4520000.0   32
# 108             POOJA  FEMALE   4520000.0   32
# 107            MAHESH    MALE   1350000.0   43
# 120           KRISHNA    MALE         NaN   22
# 106             KEDAR    MALE   3900000.0   39
# 117             KEDAR    MALE   3900000.0   39
# 105           JAGJEET    MALE   5600000.0   44
# 116            HARISH    MALE  45610000.0   42
# 104           DEEPALI  FEMALE   1300000.0   30
# 112          ASHUTOSH    MALE   9800000.0   36
# 103           ARCHANA  FEMALE   5300000.0   40
# 119            ANKUSH    MALE         NaN   32
# 101             ANKUR    MALE    100000.0   39
# ...

# %%
pd.concat([df,df], axis = 1)                    ## Same data will be concatenated rowwise
# Out:
#                  NAME  GENDER      SALARY  AGE      NAME  GENDER      SALARY  \
# Employee ID
# 101             ANKUR    MALE    100000.0   39     ANKUR    MALE    100000.0
# 102            ADITYA    MALE   1500000.0   28    ADITYA    MALE   1500000.0
# 103           ARCHANA  FEMALE   5300000.0   40   ARCHANA  FEMALE   5300000.0
# 104           DEEPALI  FEMALE   1300000.0   30   DEEPALI  FEMALE   1300000.0
# 105           JAGJEET    MALE   5600000.0   44   JAGJEET    MALE   5600000.0
# 106             KEDAR    MALE   3900000.0   39     KEDAR    MALE   3900000.0
# 107            MAHESH    MALE   1350000.0   43    MAHESH    MALE   1350000.0
# 108             POOJA  FEMALE   4520000.0   32     POOJA  FEMALE   4520000.0
# 109            PRAPTI  FEMALE   4530000.0   39    PRAPTI  FEMALE   4530000.0
# 110          SHRUTIKA  FEMALE   7850000.0   42  SHRUTIKA  FEMALE   7850000.0
# 111            SIMRAN  FEMALE   5980000.0   34    SIMRAN  FEMALE   5980000.0
# ...

# %%
pd.concat([df,df], axis = 0)                               ## Same data will be concatenated rowwise
# Out:
#                  NAME  GENDER      SALARY  AGE
# Employee ID
# 101             ANKUR    MALE    100000.0   39
# 102            ADITYA    MALE   1500000.0   28
# 103           ARCHANA  FEMALE   5300000.0   40
# 104           DEEPALI  FEMALE   1300000.0   30
# 105           JAGJEET    MALE   5600000.0   44
# 106             KEDAR    MALE   3900000.0   39
# 107            MAHESH    MALE   1350000.0   43
# 108             POOJA  FEMALE   4520000.0   32
# 109            PRAPTI  FEMALE   4530000.0   39
# 110          SHRUTIKA  FEMALE   7850000.0   42
# 111            SIMRAN  FEMALE   5980000.0   34
# 112          ASHUTOSH    MALE   9800000.0   36
# 113             SURAJ    MALE   8130000.0   47
# 114            SHWETA  FEMALE   7260000.0   47
# 115            VEDIKA  FEMALE   6360000.0   44
# 116            HARISH    MALE  45610000.0   42
# 117             KEDAR    MALE   3900000.0   39
# 118             POOJA  FEMALE   4520000.0   32
# 119            ANKUSH    MALE         NaN   32
# ...

# %%
df.value_counts()
# Out:
# NAME      GENDER  SALARY      AGE
# KEDAR     MALE    3900000.0   39     2
# POOJA     FEMALE  4520000.0   32     2
# ADITYA    MALE    1500000.0   28     1
# ANKUR     MALE    100000.0    39     1
# ARCHANA   FEMALE  5300000.0   40     1
# ASHUTOSH  MALE    9800000.0   36     1
# DEEPALI   FEMALE  1300000.0   30     1
# HARISH    MALE    45610000.0  42     1
# JAGJEET   MALE    5600000.0   44     1
# MAHESH    MALE    1350000.0   43     1
# PRAPTI    FEMALE  4530000.0   39     1
# SHRUTIKA  FEMALE  7850000.0   42     1
# SHWETA    FEMALE  7260000.0   47     1
# SIMRAN    FEMALE  5980000.0   34     1
# SURAJ     MALE    8130000.0   47     1
# VEDIKA    FEMALE  6360000.0   44     1
# Name: count, dtype: int64

# %%
df.GENDER.value_counts()
# Out:
# GENDER
# MALE      11
# FEMALE     9
# Name: count, dtype: int64

# %%
df.count()
# Out:
# NAME      20
# GENDER    20
# SALARY    18
# AGE       20
# dtype: int64

# %%
df.describe()
# Out:
#              SALARY        AGE
# count  1.800000e+01  20.000000
# mean   7.083889e+06  37.550000
# std    9.960825e+06   6.660765
# min    1.000000e+05  22.000000
# 25%    3.900000e+06  32.000000
# 50%    4.915000e+06  39.000000
# 75%    7.035000e+06  42.250000
# max    4.561000e+07  47.000000

# %%
df.AGE.mean()
# Out:
# 37.55

# %%
df.SALARY.mean()
# Out:
# 7083888.888888889

# %%
df.groupby(by = 'GENDER')['SALARY'].mean()
# Out:
# GENDER
# FEMALE    5.291111e+06
# MALE      8.876667e+06
# Name: SALARY, dtype: float64

# %%
df['CITY'] = ['PUNE', 'DELHI', 'MUMBAI', 'NAGPUR', 'PUNE', 'DELHI', 'MUMBAI', 'NAGPUR', 'PUNE', 'DELHI', 'MUMBAI', 'NAGPUR', 'PUNE', 'DELHI', 'MUMBAI', 'NAGPUR', 'PUNE', 'DELHI', 'MUMBAI', 'NAGPUR']
df
# Out:
#                  NAME  GENDER      SALARY  AGE    CITY
# Employee ID
# 101             ANKUR    MALE    100000.0   39    PUNE
# 102            ADITYA    MALE   1500000.0   28   DELHI
# 103           ARCHANA  FEMALE   5300000.0   40  MUMBAI
# 104           DEEPALI  FEMALE   1300000.0   30  NAGPUR
# 105           JAGJEET    MALE   5600000.0   44    PUNE
# 106             KEDAR    MALE   3900000.0   39   DELHI
# 107            MAHESH    MALE   1350000.0   43  MUMBAI
# 108             POOJA  FEMALE   4520000.0   32  NAGPUR
# 109            PRAPTI  FEMALE   4530000.0   39    PUNE
# 110          SHRUTIKA  FEMALE   7850000.0   42   DELHI
# 111            SIMRAN  FEMALE   5980000.0   34  MUMBAI
# 112          ASHUTOSH    MALE   9800000.0   36  NAGPUR
# 113             SURAJ    MALE   8130000.0   47    PUNE
# 114            SHWETA  FEMALE   7260000.0   47   DELHI
# 115            VEDIKA  FEMALE   6360000.0   44  MUMBAI
# 116            HARISH    MALE  45610000.0   42  NAGPUR
# ...

# %%
df.groupby(by = ['CITY', 'GENDER'])['SALARY'].mean()
# Out:
# CITY    GENDER
# DELHI   FEMALE    6.543333e+06
#         MALE      2.700000e+06
# MUMBAI  FEMALE    5.880000e+06
#         MALE      1.350000e+06
# NAGPUR  FEMALE    2.910000e+06
#         MALE      2.770500e+07
# PUNE    FEMALE    4.530000e+06
#         MALE      4.432500e+06
# Name: SALARY, dtype: float64
