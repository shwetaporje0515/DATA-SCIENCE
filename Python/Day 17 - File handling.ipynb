# %% [markdown]
# ## FILE HANDLING :
# Data used in a program is temporary; unless th edata is specificaally saved, it is lost when the program terminates.To permanently store the data created in a program. you need to save it in a file on a disk or some other permanent storage device. The dile can be transported and can be need later by other programs.
#
# Files can be classified text or binary files. A file that can be processed

# %%
f = open('abc.txt',)     # mode is not defined then as default it will go to read mode

# %%
f = open('abc.txt', 'w')              # Write mode

# %%
f.write('baba baba black sheep ')
# Out:
# 22

# %%
f.close()                             # Close file

# %%
f = open('abc.txt', 'w')              # Write mode

# %%
f.write('baba baba black sheep ')
f.write('Have you any wool ')
f.write('Yes sir yes sir three bags full ')
# Out:
# 32

# %%
f.close()

# %%
f = open('abc.txt', 'a')                # Append mode

# %%
f.write('baba baba black sheep ')
f.write('Have you any wool ')
f.write('Yes sir yes sir three bags full ')
# Out:
# 32

# %%
f = open('abc.txt', 'r')                # Read mode

# %%
f.readline()                            # This will access the data which is stored into the file
# Out:
# 'baba baba black sheep Have you any wool Yes sir yes sir three bags fullbaba baba black sheep Have you any wool Yes sir yes sir three bags fullbaba baba black sheep Have you any wool Yes sir yes sir three bags fullbaba baba black sheep Have you any wool Yes sir yes sir three bags fullbaba baba black sheep Have you any wool Yes sir yes sir three bags full baba baba black sheep Have you any wool Yes sir yes sir three bags full baba baba black sheep baba baba black sheep Have you any wool Yes sir yes sir three bags full baba baba black sheep Have you any wool Yes sir yes sir three bags full '
